# %%
import ir_datasets
dataset = ir_datasets.load("msmarco-document")
print(f"تم تحميل الداتا بنجاح! عدد الوثائق: {dataset.docs_count()}")
# Out:
# تم تحميل الداتا بنجاح! عدد الوثائق: 3213835

# %%
import os
import ir_datasets

# 1. ضبط مسار التخزين ليصبح في القرص E
# سنقوم بإنشاء مجلد باسم IR_Project_Data داخل القرص E
os.environ['IR_DATASETS_HOME'] = 'E:/IR_Project_Data'

# 2. تحميل مجموعة البيانات
print("جاري تحميل البيانات إلى القرص E، يرجى الانتظار...")
dataset1 = ir_datasets.load("msmarco-document")

print("تم التحميل بنجاح!")
print(f"عدد الوثائق: {dataset1.docs_count()}")
# Out:
# جاري تحميل البيانات إلى القرص E، يرجى الانتظار...
# تم التحميل بنجاح!
# عدد الوثائق: 3213835
